# %%
def find_second_largest(numbers_list):
    unique_numbers = list(set(numbers_list))
    
    if len(unique_numbers) < 2:
        return "List does not have a second largest number."
    
    unique_numbers.sort(reverse=True)
    return unique_numbers[1]

sample_list = [10, 20, 4, 45, 99, 99, 45]
second_largest = find_second_largest(sample_list)

print(f"Original list: {sample_list}")
print(f"Second largest number: {second_largest}")
# Out:
# Original list: [10, 20, 4, 45, 99, 99, 45]
# Second largest number: 45
